# %%
import pandas as pd
df = pd.read_csv("Admission_Predict.csv")
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 df = pd.read_csv("Admission_Predict.csv")
#       3 df
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df = df.drop(columns="Serial No.")

# %%
x = df.drop(columns="Chance of Admit")
y = df["Chance of Admit"]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test ,y_train , y_test = train_test_split(x , y , random_state=22 , test_size=0.2)

# %%
from sklearn.tree import DecisionTreeRegresso
model = DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sklearn.tree import DecisionTreeRegresso
#       2 model = DecisionTreeRegressor()
#       3 model.fit(x_train,y_train)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
y_predict = model.predict(x_test)
print(model.score(x_train,y_train))
model.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 y_predict = model.predict(x_test)
#       2 print(model.score(x_train,y_train))
#       3 model.score(x_test,y_test)
#
# NameError: name 'model' is not defined

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'max_depth': [3, 5, 7, 10],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10]
}
grid_search = GridSearchCV(DecisionTreeRegressor(),params , cv =5)
grid_search.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 7
#       1 from sklearn.model_selection import GridSearchCV
#       2 params = {
#       3     'max_depth': [3, 5, 7, 10],
#       4     'min_samples_split': [2, 10, 20],
#       5     'min_samples_leaf': [1, 5, 10]
#       6 }
# ----> 7 grid_search = GridSearchCV(DecisionTreeRegressor(),params , cv =5)
#       8 grid_search.fit(x_train,y_train)
#
# NameError: name 'DecisionTreeRegressor' is not defined

# %%
best_model = grid_search.best_estimator_
print(best_model.score(x_train,y_train))
best_model.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 best_model = grid_search.best_estimator_
#       2 print(best_model.score(x_train,y_train))
#       3 best_model.score(x_test, y_test)
#
# NameError: name 'grid_search' is not defined

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from sklearn.tree import plot_tree
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
plt.figure(figsize=(12,8))
plot_tree(best_model, filled=True, feature_names=df.columns, class_names=df["Chance of Admit"], rounded=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.figure(figsize=(12,8))
#       2 plot_tree(best_model, filled=True, feature_names=df.columns, class_names=df["Chance of Admit"], rounded=True)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(30, 18)) 

plot_tree(best_model, 
          filled=True, 
          feature_names=x_train.columns, # استخدم أعمدة التدريب مش الـ df كامل
          class_names=['No Admit', 'Admit'], # لازم تكون أسماء فئات (Strings) مش العمود نفسه
          rounded=True, 
          fontsize=10,      # تصغير الخط شوية عشان المربعات
          max_depth=5,      # أهم خطوة عشان الرسمة تكون مقروءة
          precision=2)      # تقليل الأرقام العشرية لـ 2 فقط

plt.title("Decision Tree Visualization (Truncated to Depth 3)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 from sklearn.tree import plot_tree
#       4 plt.figure(figsize=(30, 18))
#
# ModuleNotFoundError: No module named 'matplotlib'
